# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.stats import zscore

df = pd.read_csv('TotnghiepOK.csv')
df
# Out:
# C:\Users\Thuong\AppData\Local\Temp\ipykernel_13420\532994915.py:7: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('TotnghiepOK.csv')
#         Unnamed: 0       0  Unnamed: 1    SoBD  Toan   Van  Anh    Ly   Hoa  \
# 0                0       1         0.0       1   3.0  3.75  3.0   NaN   NaN
# 1                1       2         1.0       2   8.8  7.50  9.0   NaN   NaN
# 2                2       3         2.0       3   6.0  5.50  4.0  5.75  5.50
# 3                3       4         3.0       4   3.4  5.75  2.6   NaN   NaN
# 4                4       5         4.0       5   3.8  6.75  3.0   NaN   NaN
# ...            ...     ...         ...     ...   ...   ...  ...   ...   ...
# 744391      744391  744392    744391.0  744392   4.6  4.50  6.0  3.75  3.00
# 744392      744392  744393    744392.0  744393   7.0  6.00  5.0  5.25  5.50
# 744393      744393  744394    744393.0  744394   5.2  3.50  4.0  6.25  5.50
# ...

# %%
# Rời rạc hóa dl
cut_Anh_labels= ['TB','Khá','Giỏi']
cut_Anh_bins=[5,6,8,10] #0:min, 5000:max
df['Anh_Cat'] = pd.cut(df['Anh'], bins=cut_Anh_bins, labels=cut_Anh_labels)
df
# Out:
#         Unnamed: 0       0  Unnamed: 1    SoBD  Toan   Van  Anh    Ly   Hoa  \
# 0                0       1         0.0       1   3.0  3.75  3.0   NaN   NaN
# 1                1       2         1.0       2   8.8  7.50  9.0   NaN   NaN
# 2                2       3         2.0       3   6.0  5.50  4.0  5.75  5.50
# 3                3       4         3.0       4   3.4  5.75  2.6   NaN   NaN
# 4                4       5         4.0       5   3.8  6.75  3.0   NaN   NaN
# ...            ...     ...         ...     ...   ...   ...  ...   ...   ...
# 744391      744391  744392    744391.0  744392   4.6  4.50  6.0  3.75  3.00
# 744392      744392  744393    744392.0  744393   7.0  6.00  5.0  5.25  5.50
# 744393      744393  744394    744393.0  744394   5.2  3.50  4.0  6.25  5.50
# 744394      744394  744395    744394.0  744395   7.8  4.50  5.4  7.50  6.25
# 744395      744395  744396    744395.0  744396   5.8  3.50  3.0  6.25  4.75
#
# ...

# %%
df.Anh.fillna(df.Anh.mean(), inplace=True)

# %%
# Rời rạc hóa dl
cut_Anh_labels= ['TB','Khá','Giỏi']
cut_Anh_bins=[5,6,8,10] #0:min, 5000:max
df['Anh_Cat'] = pd.cut(df['Anh'], bins=cut_Anh_bins, labels=cut_Anh_labels)
df
# Out:
#         Unnamed: 0       0  Unnamed: 1    SoBD  Toan   Van  Anh    Ly   Hoa  \
# 0                0       1         0.0       1   3.0  3.75  3.0   NaN   NaN
# 1                1       2         1.0       2   8.8  7.50  9.0   NaN   NaN
# 2                2       3         2.0       3   6.0  5.50  4.0  5.75  5.50
# 3                3       4         3.0       4   3.4  5.75  2.6   NaN   NaN
# 4                4       5         4.0       5   3.8  6.75  3.0   NaN   NaN
# ...            ...     ...         ...     ...   ...   ...  ...   ...   ...
# 744391      744391  744392    744391.0  744392   4.6  4.50  6.0  3.75  3.00
# 744392      744392  744393    744392.0  744393   7.0  6.00  5.0  5.25  5.50
# 744393      744393  744394    744393.0  744394   5.2  3.50  4.0  6.25  5.50
# 744394      744394  744395    744394.0  744395   7.8  4.50  5.4  7.50  6.25
# 744395      744395  744396    744395.0  744396   5.8  3.50  3.0  6.25  4.75
#
# ...
