# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# đọc file ,hiển thị dữ liệu
df = pd.read_excel ('CollegeRecruitingData.xlsx')
df
# Out:
# C:\Users\Thuong\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
#      Years of Higher Education  Years of Experience  Age  Recruitment Bonus  \
# 0                            5                    1   31                  0
# 1                            0                    8   29                  0
# 2                            3                   11   40               1500
# 3                            1                   12   38               1500
# 4                            6                   20   42                500
# ..                         ...                  ...  ...                ...
# 495                          3                   15   37                  0
# 496                          0                    2   38                  0
# 497                          5                    5   40                  0
# ...

# %%
df[['Years of Higher Education','Years of Experience','Age','Recruitment Bonus','Calls per Day','Emails per Day']].mean()
# Out:
# Years of Higher Education      2.998
# Years of Experience           10.140
# Age                           35.418
# Recruitment Bonus            699.000
# Calls per Day                 42.282
# Emails per Day                59.578
# dtype: float64

# %%
df[['Years of Higher Education','Years of Experience','Age','Recruitment Bonus','Calls per Day','Emails per Day']].std()
# Out:
# Years of Higher Education      2.008498
# Years of Experience            6.038985
# Age                            5.919236
# Recruitment Bonus            567.929651
# Calls per Day                 22.701392
# Emails per Day                36.227569
# dtype: float64

# %%
df[['Years of Higher Education','Years of Experience','Age','Recruitment Bonus','Calls per Day','Emails per Day']].mode()
# Out:
#    Years of Higher Education  Years of Experience   Age  Recruitment Bonus  \
# 0                        4.0                  2.0  43.0                0.0
# 1                        NaN                  NaN   NaN                NaN
#
#    Calls per Day  Emails per Day
# 0             18            83.0
# 1             76             NaN

# %%
df[['Years of Higher Education','Years of Experience','Age','Recruitment Bonus','Calls per Day','Emails per Day']].quantile(.5)
# Out:
# Years of Higher Education      3.0
# Years of Experience           10.0
# Age                           36.0
# Recruitment Bonus            500.0
# Calls per Day                 44.0
# Emails per Day                58.5
# Name: 0.5, dtype: float64

# %%
df[['Years of Higher Education','Years of Experience','Age','Recruitment Bonus','Calls per Day','Emails per Day']].quantile(.25)
# Out:
# Years of Higher Education     1.0
# Years of Experience           5.0
# Age                          30.0
# Recruitment Bonus             0.0
# Calls per Day                22.0
# Emails per Day               27.0
# Name: 0.25, dtype: float64

# %%
df[['Years of Higher Education','Years of Experience','Age','Recruitment Bonus','Calls per Day','Emails per Day']].quantile(.75)
# Out:
# Years of Higher Education       5.0
# Years of Experience            15.0
# Age                            40.0
# Recruitment Bonus            1000.0
# Calls per Day                  62.0
# Emails per Day                 90.0
# Name: 0.75, dtype: float64

# %%
df.groupby('Years of Higher Education')[['Years of Experience','Age']].describe()
# Out:
#                           Years of Experience                                 \
#                                         count       mean       std  min  25%
# Years of Higher Education
# 0                                        79.0   8.974684  5.688438  0.0  3.5
# 1                                        61.0  10.983607  6.116894  1.0  6.0
# 2                                        73.0  11.821918  5.912187  0.0  7.0
# 3                                        65.0   9.261538  6.000721  0.0  3.0
# 4                                        81.0   9.456790  6.316742  0.0  3.0
# 5                                        73.0   9.958904  5.743205  0.0  5.0
# 6                                        68.0  10.779412  6.188206  0.0  6.0
#
#                                               Age                             \
#                             50%   75%   max count       mean       std   min
# Years of Higher Education
# ...

# %%
df.describe()
# Out:
#        Years of Higher Education  Years of Experience         Age  \
# count                 500.000000           500.000000  500.000000
# mean                    2.998000            10.140000   35.418000
# std                     2.008498             6.038985    5.919236
# min                     0.000000             0.000000   25.000000
# 25%                     1.000000             5.000000   30.000000
# 50%                     3.000000            10.000000   36.000000
# 75%                     5.000000            15.000000   40.000000
# max                     6.000000            20.000000   45.000000
#
#        Recruitment Bonus  Calls per Day  Emails per Day  Recruits per Month
# count         500.000000     500.000000      500.000000                 0.0
# mean          699.000000      42.282000       59.578000                 NaN
# std           567.929651      22.701392       36.227569                 NaN
# ...

# %%
sns.scatterplot(x='Years of Higher Education' , y='Years of Experience' , data=df)
# Out:
# <AxesSubplot:xlabel='Years of Higher Education', ylabel='Years of Experience'>

# %%
sns.scatterplot(x='Age' , y='Recruitment Bonus' , data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Recruitment Bonus'>

# %%
sns.scatterplot(x='Calls per Day' , y='Emails per Day' , data=df)
# Out:
# <AxesSubplot:xlabel='Calls per Day', ylabel='Emails per Day'>

# %%
sns.boxplot(data=df, x='Years of Higher Education',y='Years of Experience')
# Out:
# <AxesSubplot:xlabel='Years of Higher Education', ylabel='Years of Experience'>

# %%
sns.boxplot(data=df, x='Age' , y='Recruitment Bonus')
plt.gcf().set_size_inches(20,8)

# %%
sns.boxplot(data=df, x='Calls per Day' , y='Emails per Day')
plt.gcf().set_size_inches(18,8)

# %%
df[['Years of Higher Education','Years of Experience','Age','Recruitment Bonus','Calls per Day','Emails per Day']].mean().sort_values(ascending= False).plot(kind='bar')
plt.gcf().set_size_inches(20,8)

# %%
# vẽ bđ hist
df[['Years of Higher Education','Years of Experience','Age','Recruitment Bonus','Calls per Day','Emails per Day']].hist()
plt.gcf().set_size_inches(18,8)

# %%
df[['Years of Higher Education','Years of Experience','Age','Recruitment Bonus','Calls per Day','Emails per Day']].plot(kind='box')
plt.gcf().set_size_inches(20,8)

# %%
# vẽ bđ hệ số tương quan
cor = df[['Years of Higher Education','Years of Experience','Age','Recruitment Bonus','Calls per Day','Emails per Day']].corr()
# hiển thị chỉ số tương quan
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.gcf().set_size_inches(20,8)
