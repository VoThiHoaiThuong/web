# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.stats import zscore
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

data = pd.read_csv('105OK.csv', usecols=range(10))
data.head(10)
# Out:
#    Unnamed: 0  Access  CT du lieu  CT may tinh  CNXHKH  Chuyen de   \
# 0           0    True        True         True    True        True
# 1           1    True        True         True    True        True
# 2           2    True        True         True    True        True
# 3           3    True        True         True    True        True
# 4           4    True        True         True    True        True
# 5           5    True        True         True    True        True
# 6           6    True        True         True    True        True
# 7           7    True        True         True    True        True
# 8           8    True        True         True    True        True
# 9           9    True        True         True    True        True
#
#    CS du lieu  Cong nghe NET   CNphan mem  Dai so so hoc
# 0        True           False        True           True
# 1        True           False        True           True
# 2        True           False        True           True
# 3        True           False        True           True
# 4        True           False        True           True
# 5        True           False        True           True
# 6        True           False        True           True
# 7        True           False        True           True
# 8        True           False        True           True
# 9        True           False        True           True

# %%
data.drop('Unnamed: 0',axis=1 ,inplace=True)
data
# Out:
#     Access  CT du lieu  CT may tinh  CNXHKH  Chuyen de   CS du lieu  \
# 0     True        True         True    True        True        True
# 1     True        True         True    True        True        True
# 2     True        True         True    True        True        True
# 3     True        True         True    True        True        True
# 4     True        True         True    True        True        True
# ..     ...         ...          ...     ...         ...         ...
# 94   False        True         True    True        True        True
# 95   False        True         True    True        True        True
# 96   False        True         True    True        True        True
# 97   False        True         True    True        True        True
# 98   False       False        False   False       False       False
#
#     Cong nghe NET   CNphan mem  Dai so so hoc
# 0            False        True           True
# 1            False        True           True
# 2            False        True           True
# 3            False        True           True
# 4            False        True           True
# ..             ...         ...            ...
# 94            True        True           True
# 95            True        True           True
# 96            True        True           True
# 97            True        True           True
# 98           False       False          False
#
# [99 rows x 9 columns]

# %%
#tìm tập mục phổ biến 
frequent_itemsets = apriori(data, min_support = 0.4,use_colnames = True )
frequent_itemsets
# Out:
#       support                                           itemsets
# 0    0.525253                                           (Access)
# 1    0.989899                                       (CT du lieu)
# 2    0.979798                                      (CT may tinh)
# 3    0.989899                                           (CNXHKH)
# 4    0.979798                                       (Chuyen de )
# ..        ...                                                ...
# 378  0.464646  (CS du lieu, Chuyen de , CT may tinh, Dai so s...
# 379  0.464646  (CS du lieu, Chuyen de , Dai so so hoc, Cong n...
# 380  0.464646  (CS du lieu, Chuyen de , CT may tinh, Dai so s...
# 381  0.515152  (CS du lieu, Chuyen de , CT may tinh, Dai so s...
# 382  0.464646  (CS du lieu, Chuyen de , CT may tinh, Dai so s...
#
# [383 rows x 2 columns]

# %%
#Tìm luật kết hợp và lọc theo độ tin cậy
from mlxtend.frequent_patterns import association_rules
rules=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)
rules
# Out:
#                           antecedents  \
# 0                            (Access)
# 1                            (Access)
# 2                            (Access)
# 3                            (Access)
# 4                            (Access)
# ...                               ...
# 6045  (Cong nghe NET , Dai so so hoc)
# 6046     (Cong nghe NET , CNphan mem)
# 6047         (CNXHKH, Cong nghe NET )
# 6048     (CT du lieu, Cong nghe NET )
# 6049                 (Cong nghe NET )
#
#                                             consequents  antecedent support  \
# 0                                          (CT du lieu)            0.525253
# 1                                         (CT may tinh)            0.525253
# 2                                              (CNXHKH)            0.525253
# 3                                          (Chuyen de )            0.525253
# 4                                          (CS du lieu)            0.525253
# ...                                                 ...                 ...
# 6045  (CS du lieu, Chuyen de , CT may tinh, CNphan m...            0.464646
# 6046  (CS du lieu, Chuyen de , CT may tinh, Dai so s...            0.464646
# 6047  (CS du lieu, Chuyen de , CT may tinh, Dai so s...            0.464646
# 6048  (CS du lieu, Chuyen de , CT may tinh, Dai so s...            0.464646
# 6049  (CS du lieu, Chuyen de , CT may tinh, Dai so s...            0.464646
#
#       consequent support   support  confidence      lift  leverage  conviction
# 0               0.989899  0.525253    1.000000  1.010204  0.005306         inf
# 1               0.979798  0.515152    0.980769  1.000991  0.000510    1.050505
# 2               0.989899  0.525253    1.000000  1.010204  0.005306         inf
# 3               0.979798  0.515152    0.980769  1.000991  0.000510    1.050505
# 4               0.989899  0.525253    1.000000  1.010204  0.005306         inf
# ...                  ...       ...         ...       ...       ...         ...
# 6045            0.979798  0.464646    1.000000  1.020619  0.009387         inf
# 6046            0.979798  0.464646    1.000000  1.020619  0.009387         inf
# 6047            0.979798  0.464646    1.000000  1.020619  0.009387         inf
# 6048            0.979798  0.464646    1.000000  1.020619  0.009387         inf
# 6049            0.979798  0.464646    1.000000  1.020619  0.009387         inf
#
# [6050 rows x 9 columns]
