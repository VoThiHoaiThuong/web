# %% [markdown]
# # trực quan hóa dl vê các tp ở tiểu bang của Mỹ

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# chọn style 
plt.style.available
plt.style.use('seaborn-whitegrid')

# %%
# vẽ đồ thị matplotlib
plt.plot();

# %%
# vẽ đường thẳng, tạo dl
x = [1, 2, 3, 4]
y = [10, 8, 6, 9]
plt.plot(x,y, color="red");

# %% [markdown]
# # cách vẽ pyplot API vs OO API
# +pyplot API: vẽ nhanh chóng
# +OO API: vẽ đt khá phức tạp

# %% [markdown]
# pyplot API

# %%
#hàm trong np linspace 
x = np.linspace(0,10,1000)
# vẽ 2 dt tren 1 plot
plt.plot(x,np.sin(x), color="red", linestyle="dashed",label="sin(x)");
#muốn phân biệt sin,cos sd label
plt.plot(x,np.cos(x), color="green", label="cos(x)" );
# thêm label
plt.title("Sin(X) and Cos(X)") #tiêu đề
plt.xlabel("Bien x")
plt.ylabel("F[x]")
#giới hạn đt
#plt.xlim[0,4]
#plt.ylim[-0.7,0.6]
#plt.axis([xmin, xmax, ymin, ymax])
#plt.axis([0, 4,-0.7, 0.6])
plt.axis("equal")
plt.legend();

# %% [markdown]
# #OO API
