# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB

# %%
house_data = pd.read_csv('house.csv')
house_data
# Out:
#        Unnamed: 0         Suburb           Address  Rooms Type    Price  \
# 0               1     Abbotsford      85 Turner St      2    h  1480000
# 1               2     Abbotsford   25 Bloomburg St      2    h  1035000
# 2               4     Abbotsford      5 Charles St      3    h  1465000
# 3               5     Abbotsford  40 Federation La      3    h   850000
# 4               6     Abbotsford       55a Park St      4    h  1600000
# ...           ...            ...               ...    ...  ...      ...
# 11656       23537  Wheelers Hill      12 Strada Cr      4    h  1245000
# 11657       23538   Williamstown     77 Merrett Dr      3    h  1031000
# 11658       23539   Williamstown       83 Power St      3    h  1170000
# 11659       23541   Williamstown      96 Verdon St      4    h  2500000
# 11660       23545     Yarraville        6 Agnes St      4    h  1285000
#
#       Method   SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# ...

# %%
cut_labels = ['Low','Medium','High']
cut_bins = [0, 900000, 1200000, 10000000]
house_data['Price_lable'] = pd.cut(house_data['Price'], bins=cut_bins, labels=cut_labels)

# %%
house_data.columns
house_data.head()
y = house_data.Price_lable

house_features = ['Rooms', 'Bathroom', 'Landsize', 'Lattitude', 'Longtitude']
X = house_data[house_features]

# %%
from sklearn.model_selection import train_test_split
#CHIA DỮ LIỆU 80% TRAIN, 20% TEST
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2, random_state=3)

# %%
# Phân lớp naiv bayer
clfNB = GaussianNB()
#Train the model using the training sets y_pred=clf.predict(X_test)
clfNB.fit(X_train, y_train)
y_pred = clfNB.predict(X_test)

# %%
#Import scikit-learn metrics module để tính toán độ chính xác
from sklearn import metrics
# Độ chính xác của mô hình, phân loại có thường xuyên không?
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5409344192027432
